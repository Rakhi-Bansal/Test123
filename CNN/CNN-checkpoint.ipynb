# %%
# CNN

# cnn are 3 type
# con1d --- text **
# con2d ---- image >>>
# con3d ------------ ***


# Yann LeCun. is god father of cnn

# Convolution Layer
# Relu Activation layer
# Pooling
# flattening
# fully connected layer

# %%
# Polling  - it is scan areab by area of image .

# Polling is Dimensanality reduction techniques.

# 1. max polling
# 2. Avg Polling
# 3. Global Max Polling
# 4. Global Avg Polling

# %%
# flattening

# flettening convert polling to one Dimension.

# %%
# Feature Detector (Filter or reduce )

# it is use to detect the feature in cnn or image.
# in cnn only take odd number filter

# eg = 3*3, 5*5,7*7

# 2**n filter use Always
